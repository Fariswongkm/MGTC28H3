# %% [markdown]
# <center><h1>Exploring the Competitors</h1></center>

# %% [markdown]
# ### Part 1. Get location data using Foursquare

# %% [markdown]
# [Foursquare Places API](https://location.foursquare.com/products/places-api/) is very usefule online application used by many developers & other application like Uber etc. In this project you can used it to retrieve informtion about the places present in the neighborhoods of Toronto. The API returns a JSON file and we need to turn that into a data-frame. Here I’ve chosen similar businesses(pet grooming) for each neighborhood within a radius of 2.5km.
#
# You will need to create an account with Foursquare to access the API.  It is free to sign up, and you get $200 free credit.

# %%
import requests
import pandas as pd

# %%
toronto_DF = pd.read_csv('postalcode.csv')

# %%
display(toronto_DF)
# Out:
#              Borough Postalcode  \
# 0    Central Toronto        M4N
# 1    Central Toronto        M4P
# 2    Central Toronto        M4R
# 3    Central Toronto        M4S
# 4    Central Toronto        M4T
# ..               ...        ...
# 98              York        M6C
# 99              York        M6E
# 100             York        M6M
# 101             York        M6N
# 102             York        M9N
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                       Lawrence Park  43.728020 -79.388790
# 1                                    Davisville North  43.712751 -79.390197
# 2                                  North Toronto West  43.715383 -79.405678
# 3                                          Davisville  43.704324 -79.388790
# 4                         Moore Park, Summerhill East  43.689574 -79.383160
# ..                                                ...        ...        ...
# 98                                 Humewood-Cedarvale  43.693781 -79.428191
# 99                                Caledonia-Fairbanks  43.689026 -79.453512
# 100  Del Ray, Mount Dennis, Keelsdale and Silverthorn  43.691116 -79.476013
# 101                     Runnymede, The Junction North  43.673185 -79.487262
# 102                                            Weston  43.706876 -79.518188
#
# [103 rows x 5 columns]

# %%
# Set up your API key and other constants for Foursquare API
API_KEY = 'fsq3qoHPok1qOXZWHaA96hYcXSSajCW9rIT0MOW9RBIKrWQ='  # Replace with your actual Foursquare API key
LIMIT = 20  # Maximum number of venues to return
radius = 2000  # Search radius in meters

# a function to loop through each neighbourhood in the postalcode.csv file, and search for places
def getNearbyVenues(names, postalcode, latitudes, longitudes, radius):
    venues_list = []

    for name, postalcode, lat, lng in zip(names, postalcode, latitudes, longitudes):
        print(f"Processing neighborhood: {name}")

        # Skip if latitude or longitude is missing
        if pd.isnull(lat) or pd.isnull(lng):
            print(f"Skipping {name} due to missing latitude or longitude.")
            continue

        # Create the API request URL and parameters
        # Change the params here to customize your search, https://docs.foursquare.com/developer/reference/place-search
        # The following example looks for pet groomers in the neighbourhood
        # I am searching with categories ID 18027-Pilates Studio
        url = 'https://api.foursquare.com/v3/places/search'
        params = {
            'll': f'{lat},{lng}',
            'radius': radius,
            'limit': LIMIT,
            'categories': 18027
        }

        # Set up headers with the API key
        headers = {
            "Accept": "application/json",
            "Authorization": API_KEY
        }

        # Make the GET request
        response = requests.get(url, headers=headers, params=params)

        # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to get data for {name}. Status code: {response.status_code}")
            print(f"Error message: {response.text}")
            continue

        results = response.json()

        # Parse the JSON response
        for venue in results.get('results', []):
            # Extract venue information
            venue_name = venue.get('name')
            venue_id = venue.get('fsq_id')
            venue_location = venue.get('geocodes', {}).get('main', {})
            venue_lat = venue_location.get('latitude')
            venue_lng = venue_location.get('longitude')
            venue_categories = venue.get('categories', [])
            venue_category = venue_categories[0]['name'] if venue_categories else 'Unknown'

            # Append to the list
            venues_list.append([
                name,
                postalcode,
                lat,
                lng,
                venue_name,
                venue_id,
                venue_lat,
                venue_lng,
                venue_category
            ])

    # Create a DataFrame from the list
    nearby_venues = pd.DataFrame(venues_list, columns=[
        'Neighbourhood',
        'Postalcode',
        'Neighborhood Latitude',
        'Neighborhood Longitude',
        'Venue',
        'fsq_id',
        'Venue Latitude',
        'Venue Longitude',
        'Venue Category'
    ])

    return nearby_venues

# Example usage with your DataFrame 'toronto_DF'
# Ensure 'toronto_DF' has the columns 'Neighborhood', 'Latitude', 'Longitude'
toronto_venues = getNearbyVenues(
    names=toronto_DF['Neighbourhood'],
    postalcode=toronto_DF['Postalcode'],
    latitudes=toronto_DF['Latitude'],
    longitudes=toronto_DF['Longitude'],
    radius=radius
)

# Display the first few rows of the resulting DataFrame
toronto_venues.head(20)
# Out:
# Processing neighborhood: Lawrence Park
# Processing neighborhood: Davisville North
# Processing neighborhood: North Toronto West
# Processing neighborhood: Davisville
# Processing neighborhood: Moore Park, Summerhill East
# Processing neighborhood: Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# Processing neighborhood: Roselawn
# Processing neighborhood: Forest Hill North & West
# Processing neighborhood: The Annex, North Midtown, Yorkville
# Processing neighborhood: Rosedale
# Processing neighborhood: St. James Town, Cabbagetown
# Processing neighborhood: Church and Wellesley
# Processing neighborhood: Regent Park, Harbourfront
# Processing neighborhood: Garden District, Ryerson
# Processing neighborhood: St. James Town
# Processing neighborhood: Berczy Park
# Processing neighborhood: Central Bay Street
# Processing neighborhood: Richmond, Adelaide, King
# Processing neighborhood: Harbourfront East, Union Station, Toronto Islands
# Processing neighborhood: Toronto Dominion Centre, Design Exchange
# Processing neighborhood: Commerce Court, Victoria Hotel
# Processing neighborhood: University of Toronto, Harbord
# Processing neighborhood: Kensington Market, Chinatown, Grange Park
# Processing neighborhood: CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport
# Processing neighborhood: First Canadian Place, Underground city
# Processing neighborhood: Christie
# Processing neighborhood: Enclave of M5E
# Processing neighborhood: The Beaches
# Processing neighborhood: The Danforth West, Riverdale
# Processing neighborhood: India Bazaar, The Beaches West
# Processing neighborhood: Studio District
# Processing neighborhood: Enclave of M4L
# Processing neighborhood: Parkview Hill, Woodbine Gardens
# Processing neighborhood: Woodbine Heights
# Processing neighborhood: Leaside
# Processing neighborhood: Thorncliffe Park
# Processing neighborhood: The Danforth East
# Processing neighborhood: New Toronto, Mimico South, Humber Bay Shores
# Processing neighborhood: Alderwood, Long Branch
# Processing neighborhood: The Kingsway, Montgomery Road, Old Mill North
# Processing neighborhood: Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East
# Processing neighborhood: Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West
# Processing neighborhood: Islington Avenue
# Processing neighborhood: West Deane Park, Princess Gardens, Martin Grove, Islington, Cloverdale
# Processing neighborhood: Eringate, Bloordale Gardens, Old Burnhamthorpe, Markland Wood
# Processing neighborhood: Westmount
# Processing neighborhood: Kingsview Village, St. Phillips, Martin Grove Gardens, Richview Gardens
# Processing neighborhood: South Steeles, Silverstone, Humbergate, Jamestown, Mount Olive, Beaumond Heights, Thistletown, Albion Gardens
# Processing neighborhood: Clairville, Humberwood, Woodbine Downs, West Humber, Kipling Heights, Rexdale, Elms, Tandridge, Old Rexdale
# Processing neighborhood: Enclave of L4W
# Processing neighborhood: Hillcrest Village
# Processing neighborhood: Fairview, Henry Farm, Oriole
# Processing neighborhood: Bayview Village
# Processing neighborhood: York Mills, Silver Hills
# Processing neighborhood: Willowdale, Newtonbrook
# Processing neighborhood: Willowdale) Sout
# Processing neighborhood: York Mills West
# Processing neighborhood: Willowdale) Wes
# Processing neighborhood: Parkwoods
# Processing neighborhood: Don Mills) Nort
# Processing neighborhood: Don Mills) South (Flemingdon Park
# Processing neighborhood: Bathurst Manor, Wilson Heights, Downsview North
# Processing neighborhood: Northwood Park, York University
# Processing neighborhood: Downsview) East (CFB Toronto
# Processing neighborhood: Downsview) Wes
# Processing neighborhood: Downsview) Centra
# Processing neighborhood: Downsview) Northwes
# Processing neighborhood: Victoria Village
# Processing neighborhood: Bedford Park, Lawrence Manor East
# Processing neighborhood: Lawrence Manor, Lawrence Heights
# Processing neighborhood: Glencairn
# Processing neighborhood: North Park, Maple Leaf Park, Upwood Park
# Processing neighborhood: Humber Summit
# Processing neighborhood: Humberlea, Emery
# Processing neighborhood: Ontario Provincial Government
# Processing neighborhood: Malvern, Rouge
# Processing neighborhood: Rouge Hill, Port Union, Highland Creek
# Processing neighborhood: Guildwood, Morningside, West Hill
# Processing neighborhood: Woburn
# Processing neighborhood: Cedarbrae
# Processing neighborhood: Scarborough Village
# Processing neighborhood: Kennedy Park, Ionview, East Birchmount Park
# Processing neighborhood: Golden Mile, Clairlea, Oakridge
# Processing neighborhood: Cliffside, Cliffcrest, Scarborough Village West
# Processing neighborhood: Birch Cliff, Cliffside West
# Processing neighborhood: Dorset Park, Wexford Heights, Scarborough Town Centre
# Processing neighborhood: Wexford, Maryvale
# Processing neighborhood: Agincourt
# Processing neighborhood: Clarks Corners, Tam O'Shanter, Sullivan
# Processing neighborhood: Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Processing neighborhood: Steeles West, L'Amoreaux West
# Processing neighborhood: Upper Rouge
# Processing neighborhood: Dufferin, Dovercourt Village
# Processing neighborhood: Little Portugal, Trinity
# Processing neighborhood: Brockton, Parkdale Village, Exhibition Place
# Processing neighborhood: High Park, The Junction South
# Processing neighborhood: Parkdale, Roncesvalles
# Processing neighborhood: Runnymede, Swansea
# Processing neighborhood: Humewood-Cedarvale
# Processing neighborhood: Caledonia-Fairbanks
# Processing neighborhood: Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Processing neighborhood: Runnymede, The Junction North
# Processing neighborhood: Weston
#          Neighbourhood Postalcode  Neighborhood Latitude  \
# 0        Lawrence Park        M4N              43.728020
# 1        Lawrence Park        M4N              43.728020
# 2        Lawrence Park        M4N              43.728020
# 3     Davisville North        M4P              43.712751
# 4     Davisville North        M4P              43.712751
# 5     Davisville North        M4P              43.712751
# 6     Davisville North        M4P              43.712751
# 7     Davisville North        M4P              43.712751
# 8     Davisville North        M4P              43.712751
# 9     Davisville North        M4P              43.712751
# 10  North Toronto West        M4R              43.715383
# 11  North Toronto West        M4R              43.715383
# 12  North Toronto West        M4R              43.715383
# 13  North Toronto West        M4R              43.715383
# 14  North Toronto West        M4R              43.715383
# 15  North Toronto West        M4R              43.715383
# 16  North Toronto West        M4R              43.715383
# 17  North Toronto West        M4R              43.715383
# 18          Davisville        M4S              43.704324
# 19          Davisville        M4S              43.704324
#
#     Neighborhood Longitude                                              Venue  \
# 0               -79.388790                             Lili Viola Pilates Inc
# 1               -79.388790                                    Essence Pilates
# 2               -79.388790  Lawrence Park Chiropractic & Physiotherapy Clinic
# 3               -79.390197                                    Essence Pilates
# 4               -79.390197  Pilates-Stott Pilates Studio Equipment Sales &...
# 5               -79.390197                                        Striation 6
# 6               -79.390197                                      Stott Pilates
# 7               -79.390197  Lawrence Park Chiropractic & Physiotherapy Clinic
# 8               -79.390197                             Body Harmonics Pilates
# 9               -79.390197                              North Movement Studio
# 10              -79.405678                                    Essence Pilates
# 11              -79.405678  Pilates-Stott Pilates Studio Equipment Sales &...
# 12              -79.405678                             Body Harmonics Pilates
# 13              -79.405678                             Lili Viola Pilates Inc
# 14              -79.405678  Lawrence Park Chiropractic & Physiotherapy Clinic
# 15              -79.405678                             Body Harmonics Pilates
# 16              -79.405678                                      Stott Pilates
# 17              -79.405678                             Lili Viola Pilates Inc
# 18              -79.388790  Pilates-Stott Pilates Studio Equipment Sales &...
# 19              -79.388790                                        Striation 6
#
#                       fsq_id  Venue Latitude  Venue Longitude  Venue Category
# 0   31075a42d66e4d8e534d83a9       43.731336       -79.403600  Pilates Studio
# 1   4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 2   c8f9c54b09c341cf648d4929       43.718590       -79.401190  Massage Clinic
# 3   4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 4   4b9842fdf964a520063835e3       43.706095       -79.398446  Pilates Studio
# 5   4e278ca9a809ec0663e5d6e5       43.698445       -79.394745  Pilates Studio
# 6   6d28bac5ad31477861e67c99       43.706625       -79.398109  Pilates Studio
# 7   c8f9c54b09c341cf648d4929       43.718590       -79.401190  Massage Clinic
# 8   e2e88849bbb44eb6dc10c9ba       43.706397       -79.401256  Pilates Studio
# 9   191a326590db451f73ff78d6       43.707479       -79.375497  Pilates Studio
# 10  4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 11  4b9842fdf964a520063835e3       43.706095       -79.398446  Pilates Studio
# 12  4e558712d4c0c50afda8fb30       43.703530       -79.412873  Pilates Studio
# 13  31075a42d66e4d8e534d83a9       43.731336       -79.403600  Pilates Studio
# 14  c8f9c54b09c341cf648d4929       43.718590       -79.401190  Massage Clinic
# 15  e2e88849bbb44eb6dc10c9ba       43.706397       -79.401256  Pilates Studio
# 16  6d28bac5ad31477861e67c99       43.706625       -79.398109  Pilates Studio
# 17  7df0ad9e659c4b607b100bb5       43.729266       -79.418162  Pilates Studio
# 18  4b9842fdf964a520063835e3       43.706095       -79.398446  Pilates Studio
# 19  4e278ca9a809ec0663e5d6e5       43.698445       -79.394745  Pilates Studio

# %%
toronto_venues = toronto_venues[toronto_venues['Venue Category'] == 'Pilates Studio']
toronto_venues.head(20)
# Out:
#          Neighbourhood Postalcode  Neighborhood Latitude  \
# 0        Lawrence Park        M4N              43.728020
# 1        Lawrence Park        M4N              43.728020
# 3     Davisville North        M4P              43.712751
# 4     Davisville North        M4P              43.712751
# 5     Davisville North        M4P              43.712751
# 6     Davisville North        M4P              43.712751
# 8     Davisville North        M4P              43.712751
# 9     Davisville North        M4P              43.712751
# 10  North Toronto West        M4R              43.715383
# 11  North Toronto West        M4R              43.715383
# 12  North Toronto West        M4R              43.715383
# 13  North Toronto West        M4R              43.715383
# 15  North Toronto West        M4R              43.715383
# 16  North Toronto West        M4R              43.715383
# 17  North Toronto West        M4R              43.715383
# 18          Davisville        M4S              43.704324
# 19          Davisville        M4S              43.704324
# 20          Davisville        M4S              43.704324
# 21          Davisville        M4S              43.704324
# 22          Davisville        M4S              43.704324
#
#     Neighborhood Longitude                                              Venue  \
# 0               -79.388790                             Lili Viola Pilates Inc
# 1               -79.388790                                    Essence Pilates
# 3               -79.390197                                    Essence Pilates
# 4               -79.390197  Pilates-Stott Pilates Studio Equipment Sales &...
# 5               -79.390197                                        Striation 6
# 6               -79.390197                                      Stott Pilates
# 8               -79.390197                             Body Harmonics Pilates
# 9               -79.390197                              North Movement Studio
# 10              -79.405678                                    Essence Pilates
# 11              -79.405678  Pilates-Stott Pilates Studio Equipment Sales &...
# 12              -79.405678                             Body Harmonics Pilates
# 13              -79.405678                             Lili Viola Pilates Inc
# 15              -79.405678                             Body Harmonics Pilates
# 16              -79.405678                                      Stott Pilates
# 17              -79.405678                             Lili Viola Pilates Inc
# 18              -79.388790  Pilates-Stott Pilates Studio Equipment Sales &...
# 19              -79.388790                                        Striation 6
# 20              -79.388790                                    Essence Pilates
# 21              -79.388790                                  Core Body Science
# 22              -79.388790                             Body Harmonics Pilates
#
#                       fsq_id  Venue Latitude  Venue Longitude  Venue Category
# 0   31075a42d66e4d8e534d83a9       43.731336       -79.403600  Pilates Studio
# 1   4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 3   4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 4   4b9842fdf964a520063835e3       43.706095       -79.398446  Pilates Studio
# 5   4e278ca9a809ec0663e5d6e5       43.698445       -79.394745  Pilates Studio
# 6   6d28bac5ad31477861e67c99       43.706625       -79.398109  Pilates Studio
# 8   e2e88849bbb44eb6dc10c9ba       43.706397       -79.401256  Pilates Studio
# 9   191a326590db451f73ff78d6       43.707479       -79.375497  Pilates Studio
# 10  4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 11  4b9842fdf964a520063835e3       43.706095       -79.398446  Pilates Studio
# 12  4e558712d4c0c50afda8fb30       43.703530       -79.412873  Pilates Studio
# 13  31075a42d66e4d8e534d83a9       43.731336       -79.403600  Pilates Studio
# 15  e2e88849bbb44eb6dc10c9ba       43.706397       -79.401256  Pilates Studio
# 16  6d28bac5ad31477861e67c99       43.706625       -79.398109  Pilates Studio
# 17  7df0ad9e659c4b607b100bb5       43.729266       -79.418162  Pilates Studio
# 18  4b9842fdf964a520063835e3       43.706095       -79.398446  Pilates Studio
# 19  4e278ca9a809ec0663e5d6e5       43.698445       -79.394745  Pilates Studio
# 20  4e7518bc7d8b917602eaf409       43.714116       -79.400148  Pilates Studio
# 21  4e307348922e065e29f3b62c       43.704503       -79.366178  Pilates Studio
# 22  4e558712d4c0c50afda8fb30       43.703530       -79.412873  Pilates Studio

# %%
# The total number of pilates studios in Toronto
toronto_venues['Venue'].nunique()
# Out:
# 50

# %%
# Oberserving the number of competitors in each neighbourhood
group_counts= toronto_venues.groupby('Neighbourhood')['Venue']
group_counts.count()
# Out:
# Neighbourhood
# Bayview Village                                                                                                                            1
# Bedford Park, Lawrence Manor East                                                                                                          2
# Berczy Park                                                                                                                                6
# Brockton, Parkdale Village, Exhibition Place                                                                                               2
# CN Tower, King and Spadina, Railway Lands, Harbourfront West, Bathurst Quay, South Niagara, Island airport                                 4
# Central Bay Street                                                                                                                        15
# Christie                                                                                                                                   5
# Church and Wellesley                                                                                                                      13
# Commerce Court, Victoria Hotel                                                                                                             7
# Davisville                                                                                                                                 8
# Davisville North                                                                                                                           6
# Downsview) East (CFB Toronto                                                                                                               1
# Dufferin, Dovercourt Village                                                                                                               3
# Enclave of M5E                                                                                                                             6
# First Canadian Place, Underground city                                                                                                     7
# Forest Hill North & West                                                                                                                   5
# Garden District, Ryerson                                                                                                                  14
# Guildwood, Morningside, West Hill                                                                                                          1
# Harbourfront East, Union Station, Toronto Islands                                                                                          5
# High Park, The Junction South                                                                                                              4
# Hillcrest Village                                                                                                                          1
# Humewood-Cedarvale                                                                                                                         1
# India Bazaar, The Beaches West                                                                                                             2
# Kensington Market, Chinatown, Grange Park                                                                                                  8
# Lawrence Park                                                                                                                              2
# Leaside                                                                                                                                    3
# Little Portugal, Trinity                                                                                                                   5
# Mimico NW, The Queensway West, South of Bloor, Kingsway Park South West, Royal York South West                                             1
# Moore Park, Summerhill East                                                                                                                7
# North Toronto West                                                                                                                         7
# Old Mill South, King's Mill Park, Sunnylea, Humber Bay, Mimico NE, The Queensway East, Royal York South East, Kingsway Park South East     1
# Ontario Provincial Government                                                                                                             16
# Parkdale, Roncesvalles                                                                                                                     4
# Parkview Hill, Woodbine Gardens                                                                                                            1
# Regent Park, Harbourfront                                                                                                                  3
# Richmond, Adelaide, King                                                                                                                   8
# Rosedale                                                                                                                                  12
# Roselawn                                                                                                                                   6
# Rouge Hill, Port Union, Highland Creek                                                                                                     1
# Runnymede, Swansea                                                                                                                         3
# Runnymede, The Junction North                                                                                                              2
# St. James Town                                                                                                                             8
# St. James Town, Cabbagetown                                                                                                               15
# Studio District                                                                                                                            2
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park                                                                         12
# The Annex, North Midtown, Yorkville                                                                                                       13
# The Beaches                                                                                                                                2
# The Danforth East                                                                                                                          4
# The Danforth West, Riverdale                                                                                                               3
# The Kingsway, Montgomery Road, Old Mill North                                                                                              1
# Thorncliffe Park                                                                                                                           3
# Toronto Dominion Centre, Design Exchange                                                                                                   6
# University of Toronto, Harbord                                                                                                            16
# Willowdale) Sout                                                                                                                           1
# Willowdale, Newtonbrook                                                                                                                    1
# Woburn                                                                                                                                     1
# Woodbine Heights                                                                                                                           2
# York Mills West                                                                                                                            1
# York Mills, Silver Hills                                                                                                                   1
# Name: Venue, dtype: int64

# %%
group_counts=group_counts.count()

max_group = group_counts.idxmax()
max_group
# Out:
# 'Ontario Provincial Government'

# %% [markdown]
# ### Part 2. Interactive leaflet map using coordinate data.

# %%
import folium # map rendering library

# %%
# My example below shows pet groomers in Garden District, Ryerson
target = max_group

search_area = toronto_venues[toronto_venues['Neighbourhood'] == target]
latitude = toronto_DF[toronto_DF['Neighbourhood'] == target]['Latitude']
longitude = toronto_DF[toronto_DF['Neighbourhood'] == target]['Longitude']
display(search_area)
# Out:
#                      Neighbourhood Postalcode  Neighborhood Latitude  \
# 271  Ontario Provincial Government        M7A              43.662301
# 272  Ontario Provincial Government        M7A              43.662301
# 273  Ontario Provincial Government        M7A              43.662301
# 274  Ontario Provincial Government        M7A              43.662301
# 275  Ontario Provincial Government        M7A              43.662301
# 276  Ontario Provincial Government        M7A              43.662301
# 277  Ontario Provincial Government        M7A              43.662301
# 278  Ontario Provincial Government        M7A              43.662301
# 279  Ontario Provincial Government        M7A              43.662301
# 280  Ontario Provincial Government        M7A              43.662301
# 281  Ontario Provincial Government        M7A              43.662301
# 282  Ontario Provincial Government        M7A              43.662301
# 283  Ontario Provincial Government        M7A              43.662301
# 284  Ontario Provincial Government        M7A              43.662301
# 285  Ontario Provincial Government        M7A              43.662301
# 286  Ontario Provincial Government        M7A              43.662301
#
#      Neighborhood Longitude                          Venue  \
# 271              -79.389494                Imprint Pilates
# 272              -79.389494        Sagrario Pilates Studio
# 273              -79.389494              Yorkville Pilates
# 274              -79.389494               Pilates For Life
# 275              -79.389494                  Coyne Pilates
# 276              -79.389494                   Eden Pilates
# 277              -79.389494                     Body Mason
# 278              -79.389494     Shas Yoga & Pilates Studio
# 279              -79.389494  Live Body Wellness Consulting
# 280              -79.389494           Walker Dance Studios
# 281              -79.389494                    Mandy Mintz
# 282              -79.389494              Pilates With Stav
# 283              -79.389494          Ugly Duckling Pilates
# 284              -79.389494  Ugly Duckling Movement Studio
# 285              -79.389494                       Studio 4
# 286              -79.389494                        Barre 3
#
#                        fsq_id  Venue Latitude  Venue Longitude  Venue Category
# 271  4bb13f68f964a520d7863ce3       43.646432       -79.395056  Pilates Studio
# 272  4aeaed64f964a520b9bc21e3       43.665463       -79.381116  Pilates Studio
# 273  552fcdcb498e1648d9296c98       43.669954       -79.395815  Pilates Studio
# 274  4b27ba32f964a520068924e3       43.671943       -79.390847  Pilates Studio
# 275  4bd8a06003979c745323bdd2       43.672889       -79.384777  Pilates Studio
# 276  4f147559d5fb04999e94a665       43.674763       -79.388350  Pilates Studio
# 277  55fb37b3498edd6515930db3       43.674836       -79.388127  Pilates Studio
# 278  4fe399f7e4b07215b0198bdb       43.675472       -79.403337  Pilates Studio
# 279  4cc5c1383ed5199c91524b1e       43.646378       -79.395796  Pilates Studio
# 280  aadffd01ad104bb8624857b6       43.666475       -79.384971  Pilates Studio
# 281  ff7e4f2da4b740f1e88d516f       43.671943       -79.390847  Pilates Studio
# 282  5e3d496e14ef4c636a892e2d       43.672547       -79.389493  Pilates Studio
# 283  20e05b15a08046913a6c96df       43.674122       -79.385581  Pilates Studio
# 284  06b630ea421942ae82614c7e       43.674174       -79.385636  Pilates Studio
# 285  74ba264fa75d43ed97298846       43.648719       -79.380556  Pilates Studio
# 286  a55bd6549874496260831dc9       43.646172       -79.390901  Pilates Studio

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, venue, neighborhood in zip(search_area['Venue Latitude'], search_area['Venue Longitude'], search_area['Venue'], search_area['Neighbourhood']):
    label = '{},{}'.format(venue, neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

map_toronto
# Out:
# /opt/conda/lib/python3.11/site-packages/folium/utilities.py:94: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(coord)
# /opt/conda/lib/python3.11/site-packages/folium/utilities.py:100: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   if math.isnan(float(coord)):
# /opt/conda/lib/python3.11/site-packages/folium/utilities.py:102: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return [float(x) for x in coords]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d080f0150c8b973af0e49526bb5e628f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d080f0150c8b973af0e49526bb5e628f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d080f0150c8b973af0e49526bb5e628f = L.map(
#                 &quot;map_d080f0150c8b973af0e49526bb5e628f&quot;,
#                 {
#                     center: [43.6623015, -79.3894938],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cda1ed75f0a87f9702c8cb3d7b048f3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cda1ed75f0a87f9702c8cb3d7b048f3c.addTo(map_d080f0150c8b973af0e49526bb5e628f);
#
#
#             var circle_marker_800e56b37a9baf18aa1c770928031785 = L.circleMarker(
#                 [43.646432, -79.395056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d080f0150c8b973af0e49526bb5e628f);
#
#
#         var popup_69d3ff752029caa8db27b5736add444f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aa466f6e07ab2a0635699ec7811ed11a = $(`&lt;div id=&quot;html_aa466f6e07ab2a0635699ec7811ed11a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Imprint Pilates,Ontario Provincial Government&lt;/div&gt;`)[0];
#                 popup_69d3ff752029caa8db27b5736add444f.setContent(html_aa466f6e07ab2a0635699ec7811ed11a);
#
#
#
#         circle_marker_800e56b37a9baf18aa1c770928031785.bindPopup(popup_69d3ff752029caa8db27b5736add444f)
#         ;
#
#
#
#
#             var circle_marker_c4fb0b80bd686370b9fc695ea2fed7e4 = L.circleMarker(
#                 [43.665463, -79.381116],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d080f0150c8b973af0e49526bb5e628f);
#
#
#         var popup_83e70a229b2aae8c217fb8a1af51f213 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc4019e9d95c72b09892c3f5363ce3b8 = $(`&lt;div id=&quot;html_cc4019e9d95c72b09892c3f5363ce3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sagrario Pilates Studio,Ontario Provincial Government&lt;/div&gt;`)[0];
#                 popup_83e70a229b2aae8c217fb8a1af51f213.setContent(html_cc4019e9d95c72b09892c3f5363ce3b8);
#
#
#
#         circle_marker_c4fb0b80bd686370b9fc695ea2fed7e4.bindPopup(popup_83e70a229b2aae8c217fb8a1af51f213)
#         ;
#
#
#
#
#             var circle_marker_dbfea7ea1c4fcb7e51018c166fc1ced8 = L.circleMarker(
#                 [43.669954, -79.395815],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d080f0150c8b973af0e49526bb5e628f);
#
#
#         var popup_4af13aef548c4f0ac6deb1466bff2bbb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81df0306ece05cd46144281e442051a2 = $(`&lt;div id=&quot;html_81df0306ece05cd46144281e442051a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Yorkville Pilates,Ontario Provincial Government&lt;/div&gt;`)[0];
#                 popup_4af13aef548c4f0ac6deb1466bff2bbb.setContent(html_81df0306ece05cd46144281e442051a2);
#
#
#
#         circle_marker_dbfea7ea1c4fcb7e51018c166fc1ced8.bindPopup(popup_4af13aef548c4f0ac6deb1466bff2bbb)
#         ;
#
#
#
#
#             var circle_marker_c12608f40d423228b0867ef5a8753986 = L.circleMarker(
#                 [43.671943, -79.390847],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;:

# %%
# Set search_area to the entire toronto_venues dataset
search_area = toronto_venues

# Set the map center to the average coordinates of the dataset
latitude = toronto_venues['Venue Latitude'].mean()
longitude = toronto_venues['Venue Longitude'].mean()

# Create the map
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# Add markers for all venues in the dataset
for lat, lng, venue, neighborhood in zip(search_area['Venue Latitude'], search_area['Venue Longitude'], search_area['Venue'], search_area['Neighbourhood']):
    label = '{}, {}'.format(venue, neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# Display the resulting map
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48761d6160ec4119aca72bb7d7c46b16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48761d6160ec4119aca72bb7d7c46b16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48761d6160ec4119aca72bb7d7c46b16 = L.map(
#                 &quot;map_48761d6160ec4119aca72bb7d7c46b16&quot;,
#                 {
#                     center: [43.67314151827242, -79.39037352491695],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9d2d39bea71327708b5da927609bb47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9d2d39bea71327708b5da927609bb47.addTo(map_48761d6160ec4119aca72bb7d7c46b16);
#
#
#             var circle_marker_43a886c9f54ce84e8ec3d97727cc4544 = L.circleMarker(
#                 [43.731336, -79.4036],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48761d6160ec4119aca72bb7d7c46b16);
#
#
#         var popup_38abfa4fd1b64be6d7d39a15dd2eed60 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0064726f2dd7b4828f731e2572702f16 = $(`&lt;div id=&quot;html_0064726f2dd7b4828f731e2572702f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lili Viola Pilates Inc, Lawrence Park&lt;/div&gt;`)[0];
#                 popup_38abfa4fd1b64be6d7d39a15dd2eed60.setContent(html_0064726f2dd7b4828f731e2572702f16);
#
#
#
#         circle_marker_43a886c9f54ce84e8ec3d97727cc4544.bindPopup(popup_38abfa4fd1b64be6d7d39a15dd2eed60)
#         ;
#
#
#
#
#             var circle_marker_b7b188995457ee887755e05303842ad5 = L.circleMarker(
#                 [43.714116, -79.400148],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48761d6160ec4119aca72bb7d7c46b16);
#
#
#         var popup_35a635a2b2ab813bf7dbdbdd1f609d7b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d63743b58e63436005e547213c794f70 = $(`&lt;div id=&quot;html_d63743b58e63436005e547213c794f70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Essence Pilates, Lawrence Park&lt;/div&gt;`)[0];
#                 popup_35a635a2b2ab813bf7dbdbdd1f609d7b.setContent(html_d63743b58e63436005e547213c794f70);
#
#
#
#         circle_marker_b7b188995457ee887755e05303842ad5.bindPopup(popup_35a635a2b2ab813bf7dbdbdd1f609d7b)
#         ;
#
#
#
#
#             var circle_marker_4d24fe51879ad3fd4324fc2e54289030 = L.circleMarker(
#                 [43.714116, -79.400148],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3186cc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_48761d6160ec4119aca72bb7d7c46b16);
#
#
#         var popup_f8d1b328591621d3540858058edbd28e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c87d9adf8702b95e3cef038734f6373 = $(`&lt;div id=&quot;html_8c87d9adf8702b95e3cef038734f6373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Essence Pilates, Davisville North&lt;/div&gt;`)[0];
#                 popup_f8d1b328591621d3540858058edbd28e.setContent(html_8c87d9adf8702b95e3cef038734f6373);
#
#
#
#         circle_marker_4d24fe51879ad3fd4324fc2e54289030.bindPopup(popup_f8d1b328591621d3540858058edbd28e)
#         ;
#
#
#
#
#             var circle_marker_4a65a1db20100ec4f91b1180aabaeeb4 = L.circleMarker(
#                 [43.706095, -79.398446],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: nul

# %% [markdown]
# ### Part 3. Customer Reviews
# It seems like there is one one pet groomer withing 2km of Scarborough Village, I am interested in seeing customer's comments on Funny Bunny.  I can use [Foursquare's Place Tips API.](https://docs.foursquare.com/developer/reference/place-tips)

# %%
# a function to loop through the list of pilates studios in the neighborhood and compile all the comments related to them
def getTips(venues, fsq_ids):
    venues_tips = []

    for venue, fsq_id in zip(venues, fsq_ids):
        print(f"Processing venue: {venue}")


        # Create the API request URL and parameters
        url = f"https://api.foursquare.com/v3/places/{fsq_id}/tips"

        headers = {
            "Accept": "application/json",
            "Authorization": API_KEY
        }

        # Make the GET request
        response = requests.get(url, headers=headers)

        # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to get data for {venue}. Status code: {response.status_code}")
            print(f"Error message: {response.text}")
            continue

        results = response.json()

        # Parse the JSON response
        for tip in results:
            # Extract venue information
            tip_id = tip.get('id')
            tip_created = tip.get('created_at')
            tip_text = tip.get('text')


            # Append to the list
            venues_tips.append([
                venue,
                tip_id,
                tip_created,
                tip_text
            ])


    # Create a DataFrame from the list
    nearby_tips = pd.DataFrame(venues_tips, columns=[
        'venue_name',
        'id',
        'created_at',
        'text'
    ])


    return nearby_tips



nearby_tips = getTips(
    venues=search_area['Venue'],
    fsq_ids=search_area['fsq_id']
)

'''
for venue, fsq_id in zip(venues, fsq_ids):
    nearby_tips=getTips()
'''
# Display the first few rows of the resulting DataFrame
nearby_tips.head()
# Out:
# Processing venue: Imprint Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Yorkville Pilates
# Processing venue: Pilates For Life
# Processing venue: Coyne Pilates
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Live Body Wellness Consulting
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
#         venue_name                        id                created_at  \
# 0  Imprint Pilates  52c96ef8498e300bd8f28b28  2014-01-05T14:40:56.000Z
# 1  Imprint Pilates  5217d7f3498e58df1cee00bb  2013-08-23T21:45:23.000Z
# 2  Imprint Pilates  5217d960498e47d55cdfc99b  2013-08-23T21:51:28.000Z
# 3  Imprint Pilates  52c96fc4498e2b12ea8d5b6f  2014-01-05T14:44:20.000Z
# 4  Imprint Pilates  5217da3611d22f4dab2a8e13  2013-08-23T21:55:02.000Z
#
#                                                 text
# 0  The New Year is a great time to refocus your g...
# 1  4 week Beginners to Yoga | Thursdays September...
# 2  One On One Interview with Anita Ivic, Owner of...
# 3  5 Week Advanced Reformer Programs - $130 You'r...
# 4  Pilates focuses primarily on posture and spine...

# %%
nearby_tips.to_csv('nearby_tips_pilates.csv')

# %%
# a function to loop through the list of pilates studios and compile all the comments related to them
def getTips(venues, fsq_ids):
    venues_tips = []

    for venue, fsq_id in zip(venues, fsq_ids):
        print(f"Processing venue: {venue}")


        # Create the API request URL and parameters
        url = f"https://api.foursquare.com/v3/places/{fsq_id}/tips"

        headers = {
            "Accept": "application/json",
            "Authorization": API_KEY
        }

        # Make the GET request
        response = requests.get(url, headers=headers)

        # Check if the request was successful
        if response.status_code != 200:
            print(f"Failed to get data for {venue}. Status code: {response.status_code}")
            print(f"Error message: {response.text}")
            continue

        results = response.json()

        # Parse the JSON response
        for tip in results:
            # Extract venue information
            tip_id = tip.get('id')
            tip_created = tip.get('created_at')
            tip_text = tip.get('text')


            # Append to the list
            venues_tips.append([
                venue,
                tip_id,
                tip_created,
                tip_text
            ])


    # Create a DataFrame from the list
    nearby_tips = pd.DataFrame(venues_tips, columns=[
        'venue_name',
        'id',
        'created_at',
        'text'
    ])

    return nearby_tips

all_tips = getTips(
    venues=toronto_venues['Venue'],
    fsq_ids=toronto_venues['fsq_id']
)
# Out:
# Processing venue: Lili Viola Pilates Inc
# Processing venue: Essence Pilates
# Processing venue: Essence Pilates
# Processing venue: Pilates-Stott Pilates Studio Equipment Sales &Certification
# Processing venue: Striation 6
# Processing venue: Stott Pilates
# Failed to get data for Stott Pilates. Status code: 404
# Error message: invalid place specified: 6d28bac5ad31477861e67c99
# Processing venue: Body Harmonics Pilates
# Failed to get data for Body Harmonics Pilates. Status code: 404
# Error message: invalid place specified: e2e88849bbb44eb6dc10c9ba
# Processing venue: North Movement Studio
# Failed to get data for North Movement Studio. Status code: 404
# Error message: invalid place specified: 191a326590db451f73ff78d6
# Processing venue: Essence Pilates
# Processing venue: Pilates-Stott Pilates Studio Equipment Sales &Certification
# Processing venue: Body Harmonics Pilates
# Processing venue: Lili Viola Pilates Inc
# Processing venue: Body Harmonics Pilates
# Failed to get data for Body Harmonics Pilates. Status code: 404
# Error message: invalid place specified: e2e88849bbb44eb6dc10c9ba
# Processing venue: Stott Pilates
# Failed to get data for Stott Pilates. Status code: 404
# Error message: invalid place specified: 6d28bac5ad31477861e67c99
# Processing venue: Lili Viola Pilates Inc
# Failed to get data for Lili Viola Pilates Inc. Status code: 404
# Error message: invalid place specified: 7df0ad9e659c4b607b100bb5
# Processing venue: Pilates-Stott Pilates Studio Equipment Sales &Certification
# Processing venue: Striation 6
# Processing venue: Essence Pilates
# Processing venue: Core Body Science
# Processing venue: Body Harmonics Pilates
# Processing venue: Stott Pilates
# Failed to get data for Stott Pilates. Status code: 404
# Error message: invalid place specified: 6d28bac5ad31477861e67c99
# Processing venue: Body Harmonics Pilates
# Failed to get data for Body Harmonics Pilates. Status code: 404
# Error message: invalid place specified: e2e88849bbb44eb6dc10c9ba
# Processing venue: North Movement Studio
# Failed to get data for North Movement Studio. Status code: 404
# Error message: invalid place specified: 191a326590db451f73ff78d6
# Processing venue: Striation 6
# Processing venue: Body Mason
# Processing venue: Eden Pilates
# Processing venue: Coyne Pilates
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Striation 6
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Inhabit Pilates Movement
# Processing venue: Pilates For Life
# Processing venue: Yorkville Pilates
# Processing venue: Coyne Pilates
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Body Harmonics Pilates
# Processing venue: Essence Pilates
# Processing venue: Pilates-Stott Pilates Studio Equipment Sales &Certification
# Processing venue: Body Harmonics Pilates
# Failed to get data for Body Harmonics Pilates. Status code: 404
# Error message: invalid place specified: e2e88849bbb44eb6dc10c9ba
# Processing venue: Stott Pilates
# Failed to get data for Stott Pilates. Status code: 404
# Error message: invalid place specified: 6d28bac5ad31477861e67c99
# Processing venue: Lili Viola Pilates Inc
# Failed to get data for Lili Viola Pilates Inc. Status code: 404
# Error message: invalid place specified: 7df0ad9e659c4b607b100bb5
# Processing venue: Body Harmonics Pilates
# Processing venue: Striation 6
# Processing venue: Pilates-Stott Pilates Studio Equipment Sales &Certification
# Processing venue: Body Harmonics Pilates
# Failed to get data for Body Harmonics Pilates. Status code: 404
# Error message: invalid place specified: e2e88849bbb44eb6dc10c9ba
# Processing venue: Stott Pilates
# Failed to get data for Stott Pilates. Status code: 404
# Error message: invalid place specified: 6d28bac5ad31477861e67c99
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Inhabit Pilates Movement
# Processing venue: Yorkville Pilates
# Processing venue: Pilates For Life
# Processing venue: Body Harmonics Pilates
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Coyne Pilates
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Coyne Pilates
# Processing venue: Body Mason
# Processing venue: Eden Pilates
# Processing venue: Pilates For Life
# Processing venue: Sagrario Pilates Studio
# Processing venue: Yorkville Pilates
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Nourishing Vitality
# Failed to get data for Nourishing Vitality. Status code: 404
# Error message: invalid place specified: ab95f03cd56b450730e5d297
# Processing venue: Sagrario Pilates Studio
# Processing venue: Coyne Pilates
# Processing venue: Framewrk
# Processing venue: Have a Nice Day Pilates
# Processing venue: Riverdale Pilates
# Processing venue: Body Mason
# Processing venue: Eden Pilates
# Processing venue: Pilates For Life
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Nourishing Vitality
# Failed to get data for Nourishing Vitality. Status code: 404
# Error message: invalid place specified: ab95f03cd56b450730e5d297
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Pilates Tall and Flex Classes with Leta
# Failed to get data for Pilates Tall and Flex Classes with Leta. Status code: 404
# Error message: invalid place specified: 2145b254e26f4d891207a5c8
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Sagrario Pilates Studio
# Processing venue: Coyne Pilates
# Processing venue: Pilates For Life
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Yorkville Pilates
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Have a Nice Day Pilates
# Processing venue: Framewrk
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Imprint Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Have a Nice Day Pilates
# Processing venue: Coyne Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Pilates For Life
# Processing venue: Yorkville Pilates
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Imprint Pilates
# Processing venue: Have a Nice Day Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Live Body Wellness Consulting
# Processing venue: Framewrk
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Imprint Pilates
# Processing venue: Have a Nice Day Pilates
# Processing venue: Inner Hero Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Imprint Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Live Body Wellness Consulting
# Processing venue: Yorkville Pilates
# Processing venue: Pilates For Life
# Processing venue: Coyne Pilates
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Imprint Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inner Hero Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Have a Nice Day Pilates
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Imprint Pilates
# Processing venue: Inner Hero Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Imprint Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inner Hero Pilates
# Processing venue: Have a Nice Day Pilates
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Imprint Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inner Hero Pilates
# Processing venue: Have a Nice Day Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Imprint Pilates
# Processing venue: Yorkville Pilates
# Processing venue: Pilates For Life
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Sagrario Pilates Studio
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Coyne Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inhabit Pilates Movement
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Imprint Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inner Hero Pilates
# Processing venue: Assembly Movement
# Processing venue: Yorkville Pilates
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Imprint Pilates
# Processing venue: Inner Hero Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Imprint Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inner Hero Pilates
# Processing venue: Have a Nice Day Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Body Harmonics Pilates
# Processing venue: Inhabit Pilates Movement
# Processing venue: MISFITSTUDIO Bloor
# Processing venue: Assembly Movement
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Imprint Pilates
# Processing venue: Have a Nice Day Pilates
# Processing venue: Live Body Wellness Consulting
# Processing venue: Inner Hero Pilates
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Beach Pilates
# Processing venue: Ki Pilates Fitness
# Processing venue: Riverdale Pilates
# Processing venue: Pilates Tall and Flex Classes with Leta
# Failed to get data for Pilates Tall and Flex Classes with Leta. Status code: 404
# Error message: invalid place specified: 2145b254e26f4d891207a5c8
# Processing venue: Nourishing Vitality
# Failed to get data for Nourishing Vitality. Status code: 404
# Error message: invalid place specified: ab95f03cd56b450730e5d297
# Processing venue: Ki Pilates Fitness
# Processing venue: Beach Pilates
# Processing venue: Framewrk
# Processing venue: Have a Nice Day Pilates
# Processing venue: The Workout Loft
# Processing venue: The Workout Loft
# Processing venue: Ki Pilates Fitness
# Processing venue: Core Body Science
# Processing venue: MODALIFE Studio
# Failed to get data for MODALIFE Studio. Status code: 404
# Error message: invalid place specified: 5fc11ef7054046f2f5c55a64
# Processing venue: North Movement Studio
# Failed to get data for North Movement Studio. Status code: 404
# Error message: invalid place specified: 191a326590db451f73ff78d6
# Processing venue: Core Body Science
# Processing venue: The Workout Loft
# Processing venue: MODALIFE Studio
# Failed to get data for MODALIFE Studio. Status code: 404
# Error message: invalid place specified: 5fc11ef7054046f2f5c55a64
# Processing venue: Riverdale Pilates
# Processing venue: The Workout Loft
# Processing venue: Pilates Tall and Flex Classes with Leta
# Failed to get data for Pilates Tall and Flex Classes with Leta. Status code: 404
# Error message: invalid place specified: 2145b254e26f4d891207a5c8
# Processing venue: Nourishing Vitality
# Failed to get data for Nourishing Vitality. Status code: 404
# Error message: invalid place specified: ab95f03cd56b450730e5d297
# Processing venue: Studio Z Yoga & Fitness
# Processing venue: Barira Barre
# Processing venue: Barira Barre
# Processing venue: Cummer Park Pilates Studio
# Processing venue: Cummer Park Pilates Studio
# Processing venue: 9Movement Pilates
# Processing venue: ForME Studio
# Processing venue: 9Movement Pilates
# Processing venue: 9Movement Pilates
# Processing venue: Harmony Fitness
# Processing venue: Lili Viola Pilates Inc
# Processing venue: Lili Viola Pilates Inc
# Failed to get data for Lili Viola Pilates Inc. Status code: 404
# Error message: invalid place specified: 7df0ad9e659c4b607b100bb5
# Processing venue: Imprint Pilates
# Processing venue: Sagrario Pilates Studio
# Processing venue: Yorkville Pilates
# Processing venue: Pilates For Life
# Processing venue: Coyne Pilates
# Processing venue: Eden Pilates
# Processing venue: Body Mason
# Processing venue: Shas Yoga & Pilates Studio
# Processing venue: Live Body Wellness Consulting
# Processing venue: Walker Dance Studios
# Failed to get data for Walker Dance Studios. Status code: 404
# Error message: invalid place specified: aadffd01ad104bb8624857b6
# Processing venue: Mandy Mintz
# Failed to get data for Mandy Mintz. Status code: 404
# Error message: invalid place specified: ff7e4f2da4b740f1e88d516f
# Processing venue: Pilates With Stav
# Failed to get data for Pilates With Stav. Status code: 404
# Error message: invalid place specified: 5e3d496e14ef4c636a892e2d
# Processing venue: Ugly Duckling Pilates
# Failed to get data for Ugly Duckling Pilates. Status code: 404
# Error message: invalid place specified: 20e05b15a08046913a6c96df
# Processing venue: Ugly Duckling Movement Studio
# Failed to get data for Ugly Duckling Movement Studio. Status code: 404
# Error message: invalid place specified: 06b630ea421942ae82614c7e
# Processing venue: Studio 4
# Failed to get data for Studio 4. Status code: 404
# Error message: invalid place specified: 74ba264fa75d43ed97298846
# Processing venue: Barre 3
# Failed to get data for Barre 3. Status code: 404
# Error message: invalid place specified: a55bd6549874496260831dc9
# Processing venue: Rouge Hill Pilates
# Processing venue: The Pilates House
# Processing venue: The Pilates House
# Processing venue: MISFITSTUDIO Bloor
# Processing venue: Body Harmonics Pilates
# Processing venue: Eastward Moving Dance +Somatics
# Failed to get data for Eastward Moving Dance +Somatics. Status code: 404
# Error message: invalid place specified: 70fa750557ea41eea23e2c51
# Processing venue: Imprint Pilates
# Processing venue: Assembly Movement
# Processing venue: MISFITSTUDIO Bloor
# Processing venue: Live Body Wellness Consulting
# Processing venue: Fine Tune Pilates Parkdale
# Failed to get data for Fine Tune Pilates Parkdale. Status code: 404
# Error message: invalid place specified: d4e585cb1a18449803d7d55d
# Processing venue: Fine Tune Pilates Parkdale
# Failed to get data for Fine Tune Pilates Parkdale. Status code: 404
# Error message: invalid place specified: d4e585cb1a18449803d7d55d
# Processing venue: Underground Pilates
# Failed to get data for Underground Pilates. Status code: 404
# Error message: invalid place specified: 0c0df844567d4a78399da9d6
# Processing venue: The Loft Pilates Studio
# Processing venue: Retrofit Bodyworks Pilates
# Processing venue: Studio Z Yoga & Fitness
# Processing venue: Eastward Moving Dance +Somatics
# Failed to get data for Eastward Moving Dance +Somatics. Status code: 404
# Error message: invalid place specified: 70fa750557ea41eea23e2c51
# Processing venue: Retrofit Bodyworks Pilates
# Processing venue: Underground Pilates
# Failed to get data for Underground Pilates. Status code: 404
# Error message: invalid place specified: 0c0df844567d4a78399da9d6
# Processing venue: Fine Tune Pilates Parkdale
# Failed to get data for Fine Tune Pilates Parkdale. Status code: 404
# Error message: invalid place specified: d4e585cb1a18449803d7d55d
# Processing venue: Eastward Moving Dance +Somatics
# Failed to get data for Eastward Moving Dance +Somatics. Status code: 404
# Error message: invalid place specified: 70fa750557ea41eea23e2c51
# Processing venue: Retrofit Bodyworks Pilates
# Processing venue: Studio Z Yoga & Fitness
# Processing venue: The Loft Pilates Studio
# Processing venue: Body Harmonics Pilates
# Processing venue: Studio Z Yoga & Fitness
# Processing venue: The Loft Pilates Studio

# %%
# Display the first few rows of the resulting DataFramen
new_all_tips = all_tips.drop_duplicates(subset=['id'])

new_all_tips.head(20)
# Out:
#                                             venue_name  \
# 0    Pilates-Stott Pilates Studio Equipment Sales &...
# 1    Pilates-Stott Pilates Studio Equipment Sales &...
# 6                                           Body Mason
# 7                                        Coyne Pilates
# 9                                     Pilates For Life
# 16                              Body Harmonics Pilates
# 22                             Sagrario Pilates Studio
# 23                             Sagrario Pilates Studio
# 27                                   Riverdale Pilates
# 35                                     Imprint Pilates
# 36                                     Imprint Pilates
# 37                                     Imprint Pilates
# 38                                     Imprint Pilates
# 39                                     Imprint Pilates
# 40                                     Imprint Pilates
# 41                                     Imprint Pilates
# 42                                     Imprint Pilates
# 43                                     Imprint Pilates
# 44                                     Imprint Pilates
# 190                                    Harmony Fitness
#
#                            id                created_at  \
# 0    586d527932b0721b934da800  2017-01-04T19:52:25.000Z
# 1    4eb5f590469073bbc666b065  2011-11-06T02:48:48.000Z
# 6    5d62a28a8fc1df000698548a  2019-08-25T15:00:26.000Z
# 7    4cf29e1fb3662c0fdc127a30  2010-11-28T18:23:27.000Z
# 9    4d08db4352a4a090537224f2  2010-12-15T15:14:11.000Z
# 16   4fa55feae4b02e6a5554e845  2012-05-05T17:14:18.000Z
# 22   4aeaedbe70c603bb6ebe8eb4  2009-10-30T13:44:30.000Z
# 23   4aeaedfa70c603bb6fbe8eb4  2009-10-30T13:45:30.000Z
# 27   4be345b970c603bbfb7d9ab4  2010-05-06T22:42:01.000Z
# 35   52c96ef8498e300bd8f28b28  2014-01-05T14:40:56.000Z
# 36   5217d7f3498e58df1cee00bb  2013-08-23T21:45:23.000Z
# 37   5217d960498e47d55cdfc99b  2013-08-23T21:51:28.000Z
# 38   52c96fc4498e2b12ea8d5b6f  2014-01-05T14:44:20.000Z
# 39   5217da3611d22f4dab2a8e13  2013-08-23T21:55:02.000Z
# 40   52c96de2498ed783dab4f8a3  2014-01-05T14:36:18.000Z
# 41   521a4d0911d26cfb05b1af81  2013-08-25T18:29:29.000Z
# 42   521be21611d2176c8039a1fe  2013-08-26T23:17:42.000Z
# 43   52c96d24498e7f1bee8a049b  2014-01-05T14:33:08.000Z
# 44   5217d88911d2037352c47ad6  2013-08-23T21:47:53.000Z
# 190  4ca4b93cf88a95215b65b449  2010-09-30T16:22:20.000Z
#
#                                                   text
# 0    People there are so nice! I came for my first ...
# 1    reformer classes are amazing! check out Judi, ...
# 6                  Great instructors, welcoming space!
# 7    Excellent, outstanding personalized Pilates in...
# 9    If you love taking Amy's classes, but can't ma...
# 16             PILATES is good for you and your body!!
# 22   Call & sign up for an introductory Pilates class!
# 23                                       stretch class
# 27   These people know their stuff. Get ready for a...
# 35   The New Year is a great time to refocus your g...
# 36   4 week Beginners to Yoga | Thursdays September...
# 37   One On One Interview with Anita Ivic, Owner of...
# 38   5 Week Advanced Reformer Programs - $130 You'r...
# 39   Pilates focuses primarily on posture and spine...
# 40   @imprintpilates: READY TO GET INTO SHAPE!? Sig...
# 41   Aargh! Posh and Becks push Pilates to the limi...
# 42   Reserve Your Spot Today!!!! Prenatal Pilates |...
# 43   Happy New Year! http://conta.cc/1l0Vg7F | Adva...
# 44   Prenatal Pilates Group Class Saturdays startin...
# 190     Zumba, Kangoo, Spin, TRX, Kettling and more!!!

# %%
new_all_tips.to_csv('all_tips_pilates.csv')
